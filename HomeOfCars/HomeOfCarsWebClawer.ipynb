# %%
import requests
from lxml import etree

# %%
urlLs = []
with open('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelUrl.txt','r+') as f1:
    urls = f1.readlines()
    for url in urls:
        urlLs.append(url[:-1])

# %%
workbook = xlwt.Workbook(encoding = 'utf-8')
worksheet = workbook.add_sheet('汽车之家')
worksheet.write(0,0,'车型')
worksheet.write(0,1,'细分车型')
worksheet.write(0,2,'总评分')
worksheet.write(0,3,'总评分参与人数')
worksheet.write(0,4,'百公里油耗评分')
worksheet.write(0,5,'百公里油耗评分参与人数')
worksheet.write(0,6,'厂商指导价')
worksheet.write(0,7,'二手指导价')
worksheet.write(0,8,'正面评价标签')
worksheet.write(0,9,'负面评价标签')
worksheet.write(0,10,'空间得分')
worksheet.write(0,11,'空间得分高于/低于')
worksheet.write(0,12,'空间得分高于/低于百分比')
worksheet.write(0,13,'动力得分')
worksheet.write(0,14,'动力得分高于/低于')
worksheet.write(0,15,'动力得分高于/低于百分比')
worksheet.write(0,16,'操控得分')
worksheet.write(0,17,'操控得分高于/低于')
worksheet.write(0,18,'操控得分高于/低于百分比')
worksheet.write(0,19,'油耗得分')
worksheet.write(0,20,'油耗得分高于/低于')
worksheet.write(0,21,'油耗得分高于/低于百分比')
worksheet.write(0,22,'舒适性得分')
worksheet.write(0,23,'舒适性得分高于/低于')
worksheet.write(0,24,'舒适性得分高于/低于百分比')
worksheet.write(0,25,'外观得分')
worksheet.write(0,26,'外观得分高于/低于')
worksheet.write(0,27,'外观得分高于/低于百分比')
worksheet.write(0,28,'内饰得分')
worksheet.write(0,29,'内饰得分高于/低于')
worksheet.write(0,30,'内饰得分高于/低于百分比')
worksheet.write(0,31,'性价比得分')
worksheet.write(0,32,'性价比得分高于/低于')
worksheet.write(0,33,'性价比得分高于/低于百分比')
workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')

# %%
#use requests to get details page of a model of a car
import requests
from lxml import etree

workbook = xlwt.Workbook(encoding = 'utf-8')
worksheet = workbook.add_sheet('汽车之家')
worksheet.write(0,0,'车型')
worksheet.write(0,1,'细分车型')
worksheet.write(0,2,'总评分')
worksheet.write(0,3,'总评分参与人数')
worksheet.write(0,4,'百公里油耗评分')
worksheet.write(0,5,'百公里油耗评分参与人数')
worksheet.write(0,6,'厂商指导价')
worksheet.write(0,7,'二手指导价')
worksheet.write(0,8,'正面评价标签')
worksheet.write(0,9,'负面评价标签')
worksheet.write(0,10,'空间得分')
worksheet.write(0,11,'空间得分高于/低于')
worksheet.write(0,12,'空间得分高于/低于百分比')
worksheet.write(0,13,'动力得分')
worksheet.write(0,14,'动力得分高于/低于')
worksheet.write(0,15,'动力得分高于/低于百分比')
worksheet.write(0,16,'操控得分')
worksheet.write(0,17,'操控得分高于/低于')
worksheet.write(0,18,'操控得分高于/低于百分比')
worksheet.write(0,19,'油耗得分')
worksheet.write(0,20,'油耗得分高于/低于')
worksheet.write(0,21,'油耗得分高于/低于百分比')
worksheet.write(0,22,'舒适性得分')
worksheet.write(0,23,'舒适性得分高于/低于')
worksheet.write(0,24,'舒适性得分高于/低于百分比')
worksheet.write(0,25,'外观得分')
worksheet.write(0,26,'外观得分高于/低于')
worksheet.write(0,27,'外观得分高于/低于百分比')
worksheet.write(0,28,'内饰得分')
worksheet.write(0,29,'内饰得分高于/低于')
worksheet.write(0,30,'内饰得分高于/低于百分比')
worksheet.write(0,31,'性价比得分')
worksheet.write(0,32,'性价比得分高于/低于')
worksheet.write(0,33,'性价比得分高于/低于百分比')
workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')

for i in range(4176,len(urlLs)):
    
    print(i+1,len(urlLs))
    
    try:
        url = urlLs[i]
        headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
        r = requests.get(url,headers=headers).text
        h = etree.HTML(r)

        title = h.xpath('/html/body/div[2]/div[3]/div[1]/div/a/text()')

        goodLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" "]/text()')
        badLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" dust"]/text()')

        space = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[2]/div[2]/text()')
        HLspace = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[2]/div[3]/i/@class')
        Pspace = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[2]/div[3]/text()')

        power = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[3]/div[2]/text()')
        HLpower = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[3]/div[3]/i/@class')
        Ppower = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[3]/div[3]/text()')

        control = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[4]/div[2]/text()')
        HLcontrol = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[4]/div[3]/i/@class')
        Pcontrol = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[4]/div[3]/text()')

        cost = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[5]/div[2]/text()')
        HLcost = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[5]/div[3]/i/@class')
        Pcost = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[1]/li[5]/div[3]/text()')

        comfort = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[2]/div[2]/text()')
        HLcomfort = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[2]/div[3]/i/@class')
        Pcomfort = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[2]/div[3]/text()')

        looking = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[3]/div[2]/text()')
        HLlooking = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[3]/div[3]/i/@class')
        Plooking = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[3]/div[3]/text()')

        inner = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[4]/div[2]/text()')
        HLinner = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[4]/div[3]/i/@class')
        Pinner = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[4]/div[3]/text()')

        cost_performance = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[5]/div[2]/text()')
        HLcost_performance = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[4]/div[3]/i/@class')
        Pcost_performance = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/div/ul[2]/li[5]/div[3]/text()')

        names = [space,power,control,cost,comfort,looking,inner,cost_performance]
        HLs = [HLspace,HLpower,HLcontrol,HLcost,HLcomfort,HLlooking,HLinner,HLcost_performance]
        Ps = [Pspace,Ppower,Pcontrol,Pcost,Pcomfort,Plooking,Pinner,Pcost_performance]



        price = h.xpath('//*[@id="price"]/span[1]/a/text()')
        secondHandPrice = h.xpath('//*[@id="price"]/span[2]/a/span')

        allScore = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/ul/li[2]/span[1]/span[2]/text()')
        allPeople = h.xpath('/html/body/div[2]/div[4]/div/div/div/dl/dd/ul/li[2]/span[2]/text()')

        petrolCost = h.xpath('/html/body/div[2]/div[4]/div/div/div/div/div/div/p/span[2]/text()')
        petrolPeople = h.xpath('/html/body/div[2]/div[4]/div/div/div/div/div/div/p/text()')

        a = h.xpath('/html/body/div[2]/div[2]/div/a[4]/@href')
        newUrl = 'https://k.autohome.com.cn'+a[0]
        r = requests.get(newUrl,headers=headers).text
        h = etree.HTML(r)
        bigTitle = h.xpath('/html/body/div[4]/div[3]/div[1]/div[1]/a/text()')
        
    except:
        print(title)
    
    worksheet.write(i+1,0,bigTitle)
    worksheet.write(i+1,1,title)
    worksheet.write(i+1,2,allScore)
    worksheet.write(i+1,3,allPeople)
    
    try:
        worksheet.write(i+1,5,petrolPeople[1][7:-30])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,4,petrolCost)
        worksheet.write(i+1,6,price)
        worksheet.write(i+1,7,secondHandPrice)
        worksheet.write(i+1,8,goodLabels)
        worksheet.write(i+1,9,badLabels)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,10,space[0][38:42])
        worksheet.write(i+1,11,HLspace)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,12,Pspace[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,13,power[0][38:42])
        worksheet.write(i+1,14,HLpower)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,15,Ppower[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,16,control[0][38:42])
        worksheet.write(i+1,17,HLcontrol)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,18,Pcontrol[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,19,cost[0][38:42])
        worksheet.write(i+1,20,HLcost)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,21,Pcost[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,22,comfort[0][38:42])
        worksheet.write(i+1,23,HLcomfort)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,24,Pcomfort[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,25,looking[0][38:42])
        worksheet.write(i+1,26,HLlooking)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,27,Plooking[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,28,inner[0][38:42])
        worksheet.write(i+1,29,HLinner)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,30,Pinner[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,31,cost_performance[0][38:42])
        worksheet.write(i+1,32,HLcost_performance)
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    try:
        worksheet.write(i+1,33,Pcost_performance[1][:-34])
    except:
        workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
    workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelMoreInfo.xls')
# Out:
# 4177 4670
# 4178 4670
# 4179 4670
# 4180 4670
# 4181 4670
# 4182 4670
# 4183 4670
# 4184 4670
# 4185 4670
# 4186 4670
# 4187 4670
# 4188 4670
# 4189 4670
# 4190 4670
# 4191 4670
# 4192 4670
# 4193 4670
# 4194 4670
# 4195 4670
# 4196 4670
# 4197 4670
# 4198 4670
# 4199 4670
# 4200 4670
# 4201 4670
# 4202 4670
# 4203 4670
# 4204 4670
# 4205 4670
# 4206 4670
# 4207 4670
# 4208 4670
# 4209 4670
# 4210 4670
# 4211 4670
# 4212 4670
# 4213 4670
# 4214 4670
# 4215 4670
# 4216 4670
# 4217 4670
# 4218 4670
# ['帅铃T8 \xa02019款 2.0T汽油两驱智联型标双HFC4GA3-4D']
# 4219 4670
# 4220 4670
# 4221 4670
# 4222 4670
# 4223 4670
# 4224 4670
# 4225 4670
# 4226 4670
# 4227 4670
# 4228 4670
# 4229 4670
# 4230 4670
# 4231 4670
# 4232 4670
# 4233 4670
# 4234 4670
# 4235 4670
# 4236 4670
# 4237 4670
# 4238 4670
# 4239 4670
# 4240 4670
# 4241 4670
# 4242 4670
# 4243 4670
# 4244 4670
# 4245 4670
# 4246 4670
# 4247 4670
# 4248 4670
# 4249 4670
# 4250 4670
# 4251 4670
# 4252 4670
# 4253 4670
# 4254 4670
# 4255 4670
# ...

# %%
Pcost_perfomance
# Out:
# ['\r\n                                    4.54\r\n                                ']

# %%
looking[0][38:42]
# Out:
# '4.89'

# %%
space[0][38:42]
# Out:
# '4.03'

# %%
Pspace[1][:-34]
# Out:
# '7.6%'

# %%
Pinner[1][:-34]
# Out:
# '12.0%'

# %%
petrolPeople[1][7:-30]
# Out:
# '(106人平均值)'

# %%
url = 'https://k.autohome.com.cn/spec/34422/'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
r = requests.get(url,headers=headers).text
print(r)
h = etree.HTML(r)
secondHandPrice = h.xpath('//*[@id="price"]/span[2]/a/span')
print(secondHandPrice)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=gb2312" />
#     <title>【图】丰田_奕泽IZOA 2018款 2.0L 奕驰版 国V怎么样_缺点_优点_口碑_汽车之家</title>
#     <meta content="奕泽IZOA 2018款 2.0L 奕驰版 国V怎么样" name="keywords" />
#     <meta content="汽车之家奕泽IZOA 2018款 2.0L 奕驰版 国V口碑频道,让您准确了解奕泽IZOA 2018款 2.0L 奕驰版 国V怎么样,好不好,优点缺点有哪些,选车用车养车信息尽在汽车之家" name="description" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="renderer" content="webkit">
#     <meta http-equiv="mobile-agent" content="format=html5; url=//k.m.autohome.com.cn/spec/34422/" />
#     <script type="text/javascript" src="//s.autoimg.cn/as/js-2.0.5/sea.js"></script>
#     <script type="text/javascript" src="//x.autoimg.cn/k/js/jquery-1.7.2.min.js"></script>
#
#
#             <script type="text/javascript" src="//x.autoimg.cn/k/front/js/mobileredirect.js?v=2020033001"></script>
#
#         <link rel="canonical" href="/spec/34422/" />
# ...

# %%
/html/body/div[4]/div[5]/div/div/div[2]/a[1]

# %%
#Use requests to get details of a car's base info
import requests
import time

workbook = xlwt.Workbook(encoding = 'utf-8')
worksheet = workbook.add_sheet('汽车之家')
worksheet.write(0,0,'车型')
worksheet.write(0,1,'评分')
worksheet.write(0,2,'评分参与人数')
worksheet.write(0,3,'百公里油耗')
worksheet.write(0,4,'百公里油耗评分参与人数')
worksheet.write(0,5,'厂商指导价')
worksheet.write(0,6,'二手指导价')
worksheet.write(0,7,'正面评价标签')
worksheet.write(0,8,'负面评价标签')
worksheet.write(0,9,'一年内百车故障数')
worksheet.write(0,10,'百车故障数参与人数')
worksheet.write(0,11,'车身外观故障率')
worksheet.write(0,12,'行驶过程故障率')
worksheet.write(0,13,'功能操作故障率')
worksheet.write(0,14,'电子设备故障率')
worksheet.write(0,15,'座椅故障率')
worksheet.write(0,16,'空调系统故障率')
worksheet.write(0,17,'内饰故障率')
worksheet.write(0,18,'发动机故障率')
worksheet.write(0,19,'变速系统故障率')
workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelBaseInfo.xls')
    
for i in range(191,len(ls)):
    print(i,len(ls))
    url = 'https://k.autohome.com.cn'+ls[i]
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
    r = requests.get(url,headers=headers).text
    #print(r)
    h = etree.HTML(r)

    title = h.xpath('/html/body/div[4]/div[3]/div[1]/div[1]/a/text()')
    score = h.xpath('//*[@id="0"]/dl/dd/ul/li[2]/span[1]/span[2]/text()')
    people = h.xpath('//*[@id="0"]/dl/dd/ul/li[2]/span[2]/text()')
    petrol = h.xpath('//*[@id="0_o14T"]/div/em[1]/text()')
    petrolPeople = h.xpath('//*[@id="0_o14T"]/div/em[2]/text()')

    price = h.xpath('//*[@id="0"]/dl/dt/div[1]/span/text()')
    secondPrice = h.xpath('//*[@id="0"]/dl/dt/div[2]/span/text()')

    goodLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" "]/text()')
    badLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" dust"]/text()')

    error = h.xpath('/html/body/div[4]/div[5]/div/div/div[2]/a[1]/b/span/text()')
    errorPeople = h.xpath('/html/body/div[4]/div[5]/div/div/div[2]/a[1]/text()[2]')

    lookingError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[1]/dl/dd/span/span/text()')
    drivingError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[2]/dl/dd/span/span/text()')
    controlError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[3]/dl/dd/span/span/text()')
    eletricError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[4]/dl/dd/span/span/text()')
    chairError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[5]/dl/dd/span/span/text()')
    AcError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[6]/dl/dd/span/span/text()')
    innerError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[7]/dl/dd/span/span/text()')
    engineError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[8]/dl/dd/span/span/text()')
    speedError = h.xpath('//*[@id="quality-chart-box-01"]/div[1]/div[2]/a[9]/dl/dd/span/span/text()')

    worksheet.write(i+1,0,title)
    worksheet.write(i+1,1,score)
    worksheet.write(i+1,2,people)
    worksheet.write(i+1,3,petrol)
    worksheet.write(i+1,4,petrolPeople)
    worksheet.write(i+1,5,price)
    worksheet.write(i+1,6,secondPrice)
    worksheet.write(i+1,7,goodLabels)
    worksheet.write(i+1,8,badLabels)
    worksheet.write(i+1,9,error)
    worksheet.write(i+1,10,errorPeople)
    worksheet.write(i+1,11,lookingError)
    worksheet.write(i+1,12,drivingError)
    worksheet.write(i+1,13,controlError)
    worksheet.write(i+1,14,eletricError)
    worksheet.write(i+1,15,chairError)
    worksheet.write(i+1,16,AcError)
    worksheet.write(i+1,17,innerError)
    worksheet.write(i+1,18,engineError)
    worksheet.write(i+1,19,speedError)
    workbook.save('/Users/fowillwly/Dev/webCrawler_collection/HomeOfCars/data/modelBaseInfo.xls')
    
    time.sleep(1)

    #print(title,score,people,petrol,petrolPeople)
    #print(price,secondPrice)
    #print(koubei)
    #print(lookingError,drivingError,controlError,eletricError,chairError,AcError,innerError,engineError,speedError)
    #print(error,errorPeople)
# Out:
# 191 462
# 192 462
# 193 462
# 194 462
# 195 462
# 196 462
# 197 462
# 198 462
# 199 462
# 200 462
# 201 462
# 202 462
# 203 462
# 204 462
# 205 462
# 206 462
# 207 462
# 208 462
# 209 462
# 210 462
# 211 462
# 212 462
# 213 462
# 214 462
# 215 462
# 216 462
# 217 462
# 218 462
# 219 462
# 220 462
# 221 462
# 222 462
# 223 462
# 224 462
# 225 462
# 226 462
# 227 462
# 228 462
# 229 462
# 230 462
# 231 462
# 232 462
# 233 462
# 234 462
# 235 462
# 236 462
# 237 462
# 238 462
# 239 462
# 240 462
# 241 462
# 242 462
# 243 462
# 244 462
# 245 462
# 246 462
# 247 462
# 248 462
# 249 462
# 250 462
# 251 462
# 252 462
# 253 462
# 254 462
# 255 462
# 256 462
# 257 462
# 258 462
# 259 462
# 260 462
# 261 462
# 262 462
# 263 462
# 264 462
# 265 462
# 266 462
# 267 462
# 268 462
# 269 462
# 270 462
# 271 462
# 272 462
# 273 462
# 274 462
# 275 462
# 276 462
# 277 462
# 278 462
# 279 462
# 280 462
# 281 462
# 282 462
# 283 462
# 284 462
# 285 462
# 286 462
# 287 462
# 288 462
# 289 462
# 290 462
# ...

# %%
#use selenium to grab model url from car homepage
from selenium import webdriver
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import xlwt

for i in range(83,len(ls)):
    print(i)
    url = 'https://k.autohome.com.cn'+ls[i]
    driver = webdriver.Chrome()
    driver.get(url)
    
    try:
        driver.find_element_by_xpath('/html/body/div[2]/div[1]/span').click()
        time.sleep(0.5)
        driver.find_element_by_xpath('/html/body/div[2]/div[2]/span').click()
        time.sleep(0.5)
        driver.find_element_by_xpath('//*[@id="step02"]/a').click()
        time.sleep(0.5)
    except:
        print('不需要跳过')
        
    try:
        driver.find_element_by_xpath('//*[@id="showmorespecBtn"]').click()
        time.sleep(0.5)  
    except:
        print('不需要展开')
        
    models = driver.find_elements_by_xpath('//*[@id="specListUL"]//li/div[1]/a')
    
    for model in models:
        with open('/Users/fowillwly/Dev/webCrawler_collection/GoodDoctorWebCrawler/data/modelUrl.txt','a+') as f:
            f.write(model.get_attribute('href'))
            f.write('\n')
        print(model.get_attribute('href'))
    
    driver.quit()
# Out:
# 83
# 不需要跳过
# 不需要展开
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /usr/local/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...

# %%
#use requests to get different types of cars' urls

import requests
from lxml import etree
import time

ls = []
for att in atts:
    base = 'https://k.autohome.com.cn'
    url = base+att
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
    r = requests.get(url,headers=headers).text
    h = etree.HTML(r)

    models = h.xpath('/html/body/div[2]/div[2]/div/div/div[2]/dl/dd/ul//li/div[2]/a/@href')
    for model in models:
        ls.append(model)

# %%
ls
# Out:
# ['/3582/',
#  '/3460/',
#  '/4871/',
#  '/4690/',
#  '/4701/',
#  '/4645/',
#  '/4976/',
#  '/5394/',
#  '/4531/',
#  '/4993/',
#  '/4166/',
#  '/4305/',
#  '/5373/',
#  '/5717/',
#  '/2896/',
#  '/4646/',
#  '/3335/',
#  '/4481/',
#  '/3664/',
#  '/4887/',
#  '/4247/',
#  '/3292/',
#  '/2615/',
#  '/4072/',
#  '/3035/',
#  '/5240/',
#  '/4099/',
#  '/4069/',
#  '/4824/',
#  '/3397/',
#  '/4473/',
#  '/5317/',
#  '/3495/',
#  '/4353/',
#  '/3234/',
#  '/3429/',
#  '/2778/',
#  '/5261/',
#  '/5270/',
#  '/5267/',
#  '/5710/',
#  '/3924/',
#  '/4615/',
#  '/5118/',
#  '/4879/',
#  '/2123/',
#  '/314/',
#  '/5178/',
#  '/5565/',
#  '/770/',
#  '/5179/',
#  '/5393/',
#  '/5586/',
#  '/4080/',
#  '/4745/',
#  '/656/',
#  '/3788/',
#  '/2951/',
#  '/5385/',
#  '/2561/',
#  '/5472/',
#  '/5211/',
#  '/3248/',
#  '/5348/',
#  '/4898/',
#  '/2987/',
#  '/564/',
#  '/5309/',
#  '/3968/',
#  '/5498/',
#  '/5194/',
#  '/4856/',
#  '/3691/',
#  '/4631/',
#  '/623/',
#  '/4147/',
#  '/4674/',
# ...

# %%
ls
# Out:
# ['/3582/',
#  '/3460/',
#  '/4871/',
#  '/4690/',
#  '/4701/',
#  '/4645/',
#  '/4976/',
#  '/5394/',
#  '/4531/',
#  '/4993/',
#  '/4166/',
#  '/4305/',
#  '/5373/',
#  '/5717/',
#  '/2896/',
#  '/4646/',
#  '/3335/',
#  '/4481/',
#  '/3664/',
#  '/4887/',
#  '/4247/',
#  '/3292/',
#  '/2615/',
#  '/4072/',
#  '/3035/',
#  '/5240/',
#  '/4099/',
#  '/4069/',
#  '/4824/',
#  '/3397/',
#  '/4473/',
#  '/5317/',
#  '/3495/',
#  '/4353/',
#  '/3234/',
#  '/3429/',
#  '/2778/',
#  '/5261/',
#  '/5270/',
#  '/5267/',
#  '/5710/',
#  '/3924/',
#  '/4615/',
#  '/5118/',
#  '/4879/',
#  '/2123/',
#  '/314/',
#  '/5178/',
#  '/5565/',
#  '/770/',
#  '/5179/',
#  '/5586/',
#  '/5393/',
#  '/4080/',
#  '/4745/',
#  '/656/',
#  '/3788/',
#  '/2951/',
#  '/2561/',
#  '/5385/',
#  '/5472/',
#  '/5211/',
#  '/3248/',
#  '/5348/',
#  '/4898/',
#  '/2987/',
#  '/564/',
#  '/5309/',
#  '/5498/',
#  '/5194/',
#  '/3968/',
#  '/4856/',
#  '/3691/',
#  '/4631/',
#  '/623/',
#  '/4147/',
#  '/4674/',
# ...

# %%
# Out:
# 462

# %%
len(ls)
# Out:
# 462

# %%
for i in range(len(urlLs)):
    print(i)
    
    url = urlLs[i]
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
    r = requests.get(url,headers=headers).text
    #print(r)
    h = etree.HTML(r)
    
    #goodLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" "]/text()')
    #badLabels = h.xpath('//*[@id="tab-10"]/div[2]/div//*[@class=" dust"]/text()')
    
    a = h.xpath('/html/body/div[2]/div[2]/div/a[4]/@href')
    newUrl = 'https://k.autohome.com.cn'+a[0]
    print(newUrl)
    r1 = requests.get(newUrl,headers=headers).text
    #print(r1)
    h1 = etree.HTML(r1)
    bigTitle = h1.xpath('/html/body/div[4]/div[3]/div[1]/div[1]/a/text()')
    
    
    print(bigTitle)
# Out:
# 0
# https://k.autohome.com.cn/3582/
# ['东风本田-本田XR-V']
# 1
# https://k.autohome.com.cn/3582/
# ['东风本田-本田XR-V']
# 2
# https://k.autohome.com.cn/3582/
# ['东风本田-本田XR-V']
# 3
# https://k.autohome.com.cn/3582/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-208-3f8477b5e12b> in <module>
#      17     #print(r1)
#      18     h1 = etree.HTML(r1)
# ---> 19     bigTitle = h1.xpath('/html/body/div[4]/div[3]/div[1]/div[1]/a/text()')
#      20
#      21
#
# KeyboardInterrupt:
