# %%
from selenium import webdriver
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

url = 'https://www.linkedin.com/in/红军-于-168268121/'

driver = webdriver.Chrome()
driver.get(url)
time.sleep(1)
login = driver.find_element_by_xpath('/html/body/main/div/div/form[2]/section/p/a')
login.click()
time.sleep(1)
nameBox = driver.find_element_by_xpath('//*[@id="login-email"]')
passwordBox = driver.find_element_by_xpath('//*[@id="login-password"]')
nameBox.send_keys('username')
passwordBox.send_keys('password')

driver.find_element_by_xpath('//*[@id="login-submit"]').click()

# %%
xpath = '/html/body/section/section[3]/section[1]/a'
/html/body/section/section[3]/section[2]/a

# %%
import requests
import time
from lxml import etree

# %%
url = 'https://m.haodf.com/doctorteam/5814283554-zixun.htm'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'}
r = requests.get(url,headers=headers).text
print(r)
h = etree.HTML(r)
# Out:
# <!DOCTYPE html>
# <html>
# <head lang="en">
#     <meta charset="UTF-8">
#     <title>咨询列表 - 好大夫在线</title>
#     <meta name="format-detection" content="telephone=no,email=no,address=no"/>
#     <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport">
#     <link href="//i2.hdfimg.com/ssi/ndoctorteam/doctorteam/prd/style/release/consultationlist@5a5240abbe6bf7c73bee53d32e941295.css" rel="stylesheet">
# <script src="//i2.hdfimg.com/js/seagullbegin.js" ></script></head>
# <body>
# <section class="view">
#     <link href="//i1.hdfimg.com/ssi/css/hdfNavCustom1001_v2.css?20190911" rel="stylesheet">
#           <header id="hdf-nav-custom-1001" class="hdf-nav-custom-1001" style="background-color: #176ACC;">
#               <a class="hdf-nav-custom-goBackIndex" href="/"><img class="hdf-n-c-goBackLogo" src="//i1.hdfimg.com/ssi/image/hdfNavCustom1001-logo.png" alt="logo"></a>
#               <a class="hdf-nav-custom-goSearch js-hdf-nav" href="javascript:;" style="display:none">导航</a>
#               <a class="hdf-nav-custom-goSearch" href="/">首页</a>
#               <a class="hdf-nav-custom-goHome" href="/nusercenter/index" ><span class="hdf-n-c-showNum js-hdf-n-c-showNum"></span>我的</a>
#           </header>
#           <section id="wap-head-nav">
#                         <div class="wap-head-nav js-wap-head-nav" style="display: none;">
#                             <div class="w-h-n-arrow"></div>
#                              <form class="w-h-n-form" id="uniqueSearchForm20151125">
#                                  <div class="w-h-n-f-box">
#                                      <a class="w-h-n-f-b-txt" href="/touch/search/search">医院名、疾病名或医生姓名</a>
#                                      <a class="w-h-n-f-b-btn" href="/touch/search/search">搜索</a>
#
#                                  </div>
#                              </form>
#                             <div class="w-h-n-btnlink">
#                                 <a href="/touch/province/list.htm?nav_ref=" class="w-h-n-b-a w-h-n-b-left" id="cnzz_yiyuan203">按医院找医生</a>
#                                 <a href="/touch/jibing/list.htm?nav_ref=" class="w-h-n-b-a w-h-n-b-right" id="cnzz_jibing204">按疾病找医生</a>
#                             </div>
#
#                             <div class="w-h-n-imglink">
#                                 <a class="w-h-n-i-a w-h-n-i-left" href="/touch/newcase/askdoctorlist " id="cnzz_zixun205"></a>
#                                 <a class="w-h-n-i-a w-h-n-i-center" href="/touch/case/callin?nav_ref=" id="cnzz_dianhua206"></a>
#                                 <a class="w-h-n-i-a w-h-n-i-right" href="/menzhen/" id="cnzz_jihao207"></a>
#                             </div>
#                             <div class="w-h-n-imglink w-h-n-center">
#                                 <a class="w-h-n-i-a w-h-n-i-jinri" href="/nconsult/nethospital/cliniclist" id="cnzz-jinrimenzhen211"></a>
#                                 <a class="w-h-n-i-a w-h-n-i-jisu" href="/touch/netcase/nindexJumpSpeedCase?childrenBizType=SpeedCase" id="cnzz-jisuwenzhen212"></a>
#                             </div>
#                             <div class="w-h-n-link clearfix">
#                                 <a class="w-h-n-link-a" href="/touch/?nav_ref=" id="cnzz_shouye208">首页</a>
#                                 <a class="w-h-n-link-a" href="/touch/disease/diseasepopularscience?nav_ref=" id="cnzz_zhishi209">疾病知识</a>
#                                 <a class="w-h-n-link-a" href="/p?nav_ref=" id="cnzz_xizai210">下载客户端</a>
#                             </div>
#                             <div class="w-h-n-line js-w-h-n-line" >
#                             </div>
#                             <div class="w-h-n-bottom">
#                                 <div class="w-h-n-b-radius"></div>
#                             </div>
#
#                         </div>
#                         <div class="wap-head-mask js-wap-head-mask" style="display: none;"></div>
#                     </section>
#           <script>
#
#             var whenReady = (function () {
#               var funcs = [
#               ];
#               var ready = false;
#               function handler(e) {
#                 if (ready)
#                 return;
#                 if (e.type === 'onreadystatechange' && document.readyState !== 'complete') {
#                   return;
#                 }
#                 for (var i = 0; i < funcs.length; i++) {
#                   funcs[i].call(document);
#                 }
#                 ready = true;
#                 funcs = null;
#               }
#               if (document.addEventListener) {
#                 document.addEventListener('DOMContentLoaded', handler, false);
#                 document.addEventListener('readystatechange', handler, false); //IE9+
#                 window.addEventListener('load', handler, false);
#               } else if (document.attachEvent) {
#                 document.attachEvent('onreadystatechange', handler);
#                 window.attachEvent('onload', handler);
#               }
#               return function whenReady(fn) {
#                 if (ready) {
#                   fn.call(document);
#                 }
#                 else {
#                   funcs.push(fn);
#                 }
#               }
#             }) ();
#
#             whenReady(function(){
#               var script = document.createElement("script");
#                           script.type = "text/javascript";
#                           script.src = '//i1.hdfimg.com/ssi/js/hdfNavCustom1001_v2.js?20181128';
#                           document.body.appendChild(script);
#             })
#                     </script>
#     <section class="breadcrumb">
#     	<div>
#     		<a class="breadcrumb-item" href="//m.haodf.com/touch/doctor/DE4r0Fy0C9LuSlTjvx3676J1SHSYhq37w.htm">张振</a>
#     		<a class="breadcrumb-item" href="//m.haodf.com/doctorteam/5804632836.htm">张振皮肤美容专家团队</a>
#     		<h1 class="breadcrumb-item breadcrumb-active">专家团队咨询列表</h1>
#     	</div>
#     </section>
#     <section class="conlist">
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6480492786.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">私人医生服务</p>
#                     <span class="conlist-item-tip">共<i>4</i>条对话&nbsp;<i class="conlist-item-date">今天</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：毛孔粗大</span>
#                 <span class="fr conlist-item-status">广东广州</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6480272479.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title
span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6475627170.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">脸部皮肤长了个痘痘一样的东西，捏着有点痛 脸部长了颗很大的痘痘一样的东西</p>
#                     <span class="conlist-item-tip">共<i>4</i>条对话&nbsp;<i class="conlist-item-date">02.15</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：脸部皮肤长了个痘痘一样的东西，捏着有点痛</span>
#                 <span class="fr conlist-item-status">浙江丽水</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6473608160.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">私人医生服务</p>
#                     <span class="conlist-item-tip">共<i>24</i>条对话&nbsp;<i class="conlist-item-date">01.25</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：面部色斑问题</span>
#                 <span class="fr conlist-item-status">江苏无锡</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6474156541.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">痤疮,去毛孔 痤疮</p>
#                     <span class="conlist-item-tip">共<i>11</i>条对话&nbsp;<i class="conlist-item-date">01.24</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：痤疮;去毛孔</span>
#                 <span class="fr conlist-item-status">江苏苏州</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6474019095.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">鼻子上增生性疤痕和红肿痘痘 怎么去除鼻子上的增生痘疤 /如何控制鼻子上红肿痘痘</p>
#                     <span class="conlist-item-tip">共<i>11</i>条对话&nbsp;<i class="conlist-item-date">01.16</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：鼻子上增生性疤痕和红肿痘痘</span>
#                 <span class="fr conlist-item-status">浙江宁波</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6473986704.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">出生一段时间，脸出现咖啡斑 咖啡斑，咖啡斑</p>
#                     <span class="conlist-item-tip">共<i>11</i>条对话&nbsp;<i class="conlist-item-date">01.15</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：出生一段时间，脸出现咖啡斑</span>
#                 <span class="fr conlist-item-status">福建泉州</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6468752821.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">女孩，20岁，左脸太田痣，预约手术谢谢。 女孩左脸太田痣，急！预约张振医生门诊手术，谢谢！</p>
#                     <span class="conlist-item-tip">共<i>13</i>条对话&nbsp;<i class="conlist-item-date">01.14</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：女孩，20岁，左脸太田痣，预约手术谢谢。</span>
#                 <span class="fr conlist-item-status">黑龙江齐齐哈尔</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#             <section class="conlist-item">
#                 <a href="/doctorteam/flow_team_6473227261.htm">
#                 </a>
#                 <div class="conlist-item-header">
#                     <p class="conlist-item-title">私人医生服务</p>
#                     <span class="conlist-item-tip">共<i>42</i>条对话&nbsp;<i class="conlist-item-date">01.09</i>
#         							</span>
#                 </div>
#                 <div class="conlist-item-p">
#                 <span class="conlist-item-diss">疾病：雀斑，黄褐斑，老年斑想做皮秒激光</span>
#                 <span class="fr conlist-item-status">浙江绍兴</span>
#             </div>
#                 <p class="conlist-item-p conlist-item-con"></p>
#
#             </section>
#     </section>
# </section>
# <script type="text/javascript">
#     window.PAGE_DATA = {
#         loadFlag: true,
#         pages: 15,
#         doctorTeamHotId:5814283554,
#         userId:0,
#     };
# </script>
# <script type="text/javascript" src="//i2.hdfimg.com/ssi/ndoctorteam/doctorteam/prd/script/release/consultationlist@15737105f5e3167f097df7acde9d0d26.js?dffiii"></script>
# <script src="//i1.hdfimg.com/js/pvstat.js?20171101" type="text/javascript" charset="utf-8"></script>
# <script src="https://i1.hdfimg.com/ssi/js/pushstat.js" type="text/javascript"></script>
# </body>
# </html>

# %%
/html/body/section/section[3]/section[1]/a
